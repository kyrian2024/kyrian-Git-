# %% [markdown]
# # Course Title: Python Project For Data Science

# %% [markdown]
# ## Name : Kierian Ikechukwu Uzochukwu

# %% [markdown]
# ### Question 1 - Extracting Tesla Stock Data Using yfinance - 2 Points

# %%
#Installing yfinance
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing the following library to accomplish this task 
import yfinance as yf
import pandas as pd
from bs4 import BeautifulSoup
import requests
import pandas as pd
from pandas import DataFrame, Series
import pandas as pdt

# %%
ticker = 'TSLA'

# %%
tesla = yf.Ticker(ticker)

# %%
tesla.history(period='max')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2024-10-14 00:00:00-04:00  220.130005  221.910004  213.740005  219.160004
# 2024-10-15 00:00:00-04:00  220.009995  224.259995  217.119995  219.570007
# 2024-10-16 00:00:00-04:00  221.399994  222.820007  218.929993  221.330002
# 2024-10-17 00:00:00-04:00  221.589996  222.080002  217.899994  220.889999
# 2024-10-18 00:00:00-04:00  220.710007  222.279999  219.229996  220.699997
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# ### Question 2 - Extracting Tesla Revenue Data Using Webscraping - 1 Points

# %%
url =  "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"

# %%
kierian = requests.get(url)

# %%
soup = BeautifulSoup(kierian.text, "html")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue" rel="canonical"/>
# <title>Tesla Revenue 2010-2022 | TSLA | MacroTrends</title>
# <meta content="Tesla annual/quarterly revenue history and growth rate from 2010 to 2022. Revenue can be defined as the amount of money a company receives from its customers in exchange for the sales of goods or services.  Revenue is the top line item on an income statement from which all costs and expenses are subtracted to arrive at net income.
#
# 				&lt;ul style='margin-top:10px;'&gt;
# ...

# %%
# Parse the HTML content using Beautiful Soup
soup = BeautifulSoup(kierian.content, 'html.parser')

# %%
# Find the revenue data table
table = soup.find('table', {'class': 'revenue-table'})

# %%
table = soup.find('table')

# %%
row = table.find_all('tr')

# %%
print(table)
# Out:
# <table class="historical_data_table table">
# <thead>
# <tr>
# <th colspan="2" style="text-align:center">Tesla Annual Revenue<br/><span style="font-size:14px;">(Millions of US $)</span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:center">2021</td>
# <td style="text-align:center">$53,823</td>
# </tr>
# <tr>
# <td style="text-align:center">2020</td>
# <td style="text-align:center">$31,536</td>
# </tr>
# <tr>
# <td style="text-align:center">2019</td>
# <td style="text-align:center">$24,578</td>
# </tr>
# <tr>
# <td style="text-align:center">2018</td>
# <td style="text-align:center">$21,461</td>
# </tr>
# <tr>
# <td style="text-align:center">2017</td>
# <td style="text-align:center">$11,759</td>
# </tr>
# <tr>
# <td style="text-align:center">2016</td>
# <td style="text-align:center">$7,000</td>
# </tr>
# <tr>
# <td style="text-align:center">2015</td>
# <td style="text-align:center">$4,046</td>
# </tr>
# <tr>
# <td style="text-align:center">2014</td>
# ...

# %%
print(row)
# Out:
# [<tr>
# <th colspan="2" style="text-align:center">Tesla Annual Revenue<br/><span style="font-size:14px;">(Millions of US $)</span></th>
# </tr>, <tr>
# <td style="text-align:center">2021</td>
# <td style="text-align:center">$53,823</td>
# </tr>, <tr>
# <td style="text-align:center">2020</td>
# <td style="text-align:center">$31,536</td>
# </tr>, <tr>
# <td style="text-align:center">2019</td>
# <td style="text-align:center">$24,578</td>
# </tr>, <tr>
# <td style="text-align:center">2018</td>
# <td style="text-align:center">$21,461</td>
# </tr>, <tr>
# <td style="text-align:center">2017</td>
# <td style="text-align:center">$11,759</td>
# </tr>, <tr>
# <td style="text-align:center">2016</td>
# <td style="text-align:center">$7,000</td>
# </tr>, <tr>
# <td style="text-align:center">2015</td>
# <td style="text-align:center">$4,046</td>
# </tr>, <tr>
# <td style="text-align:center">2014</td>
# <td style="text-align:center">$3,198</td>
# </tr>, <tr>
# <td style="text-align:center">2013</td>
# ...

# %% [markdown]
# ### Question 3 - Extracting GameStop Stock Data Using yfinance - 2 Points

# %%
ticker = 'GME'

# %%
gamestop = yf.Ticker('GME')

# %%
gamestop.history(period='max')
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2002-02-13 00:00:00-05:00   1.620129   1.693350   1.603296   1.691667
# 2002-02-14 00:00:00-05:00   1.712707   1.716074   1.670626   1.683250
# 2002-02-15 00:00:00-05:00   1.683250   1.687458   1.658002   1.674834
# 2002-02-19 00:00:00-05:00   1.666418   1.666418   1.578047   1.607504
# 2002-02-20 00:00:00-05:00   1.615920   1.662210   1.603296   1.662210
# ...                              ...        ...        ...        ...
# 2024-10-14 00:00:00-04:00  20.750000  21.670000  20.459999  21.330000
# 2024-10-15 00:00:00-04:00  21.450001  21.680000  20.980000  21.270000
# 2024-10-16 00:00:00-04:00  21.129999  21.750000  21.030001  21.660000
# 2024-10-17 00:00:00-04:00  21.500000  21.660000  21.230000  21.410000
# 2024-10-18 00:00:00-04:00  21.410000  21.610001  20.980000  21.219999
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# ### Question 4 - Extracting GameStop Revenue Data Using Webscraping - 1 Points

# %%
url =  "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html"

# %%
kie = requests.get(url)

# %%
soup = BeautifulSoup(kie.text, "html")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ### Question 5 - Tesla Stock and Revenue Dashboard - 2 Points

# %%
pip install dash plotly pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
#Fetch tesla stock data
tesla_stock = yf.Ticker('TSLA')

# %%
#Get historical stock data
stock_data = tesla_stock.history(period='5y')

# %%
# Plot the closing prices
plt.figure(figsize=(10, 6))
plt.plot(stock_data.index, stock_data['Close'], label='Tesla Stock Price')
plt.title('Tesla Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Question 6 - GameStop Stock and Revenue Dashboard- 2 Points

# %%
#Fetch tesla stock data
gamestop_stock = yf.Ticker('GME')

# %%
#Get historical stock data
stock_data = gamestop_stock.history(period='5y')

# %%
# Plot the closing prices
plt.figure(figsize=(10, 6))
plt.plot(stock_data.index, stock_data['Close'], label='gamestop Stock Price')
plt.title('gamestop Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Thank you Coursera for the this opportunity to learn data science am really grateful to you guys
